# %% [markdown]
# # IOM Data Preprocessing Notebook

# %%
RAW_DIR = '../raw'
OUT_DIR = '../iom_out'
MAKE_SYNTH = True
CORE_THRESHOLD = 0.20

# %%
import sys, subprocess
subprocess.run([sys.executable, '../src/iom_build.py', '--raw_dir', RAW_DIR, '--out_dir', OUT_DIR, '--make_synth', '--core_threshold', str(CORE_THRESHOLD)], check=False)

# %%
import sys, subprocess
subprocess.run([sys.executable, '../src/iom_validate.py', '--out_dir', OUT_DIR], check=False)
